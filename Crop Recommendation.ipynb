# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report
from sklearn import metrics
from sklearn import tree
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
for dirname, _, filenames in os.walk('/content/drive/MyDrive/AI Lab Project'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /content/drive/MyDrive/AI Lab Project/May2019IJCSECropRecommendationSystemforPrecisionAgriculture.pdf
# /content/drive/MyDrive/AI Lab Project/CropRecommendationSystem.pdf
# /content/drive/MyDrive/AI Lab Project/crop prediction/NBClassifier.pkl
# /content/drive/MyDrive/AI Lab Project/crop prediction/DecisionTree.pkl
# /content/drive/MyDrive/AI Lab Project/crop prediction/RandomForest.pkl
# /content/drive/MyDrive/AI Lab Project/crop prediction/Crop Recommendation.ipynb
# /content/drive/MyDrive/AI Lab Project/crop prediction/Crop_prediction.csv
# /content/drive/MyDrive/AI Lab Project/crop prediction/.ipynb_checkpoints/Crop Recommendation-checkpoint.ipynb

# %%
df = pd.read_csv('/content/drive/MyDrive/ PROJECT/Database/Crop_recommendation - Crop_recommendation.csv')
df
# Out:
#       Nitrogen  phosphorus  potassium  ...        ph    rainfall  Crops
# 0         90.0        42.0       43.0  ...  6.502985  202.935536   rice
# 1         85.0        58.0       41.0  ...  7.038096  226.655537   rice
# 2         60.0        55.0       44.0  ...       NaN  263.964248   rice
# 3         74.0        35.0       40.0  ...  6.980401  242.864034   rice
# 4         78.0        42.0       42.0  ...  7.628473  262.717340   rice
# ...        ...         ...        ...  ...       ...         ...    ...
# 2195     107.0        34.0       32.0  ...  6.780064  177.774507    Tea
# 2196      99.0        15.0       27.0  ...  6.086922  127.924610    Tea
# 2197     118.0        33.0       30.0  ...  6.362608  173.322839    Tea
# 2198     117.0        32.0       34.0  ...  6.758793  127.175293    Tea
# 2199     104.0        18.0       30.0  ...  6.779833  140.937041    Tea
#
# [2200 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Nitrogen     2163 non-null   float64
#  1   phosphorus   2139 non-null   float64
#  2   potassium    2135 non-null   float64
#  3   temperature  2137 non-null   float64
#  4   humidity     2129 non-null   float64
#  5   ph           2048 non-null   float64
#  6   rainfall     2158 non-null   float64
#  7   Crops        2200 non-null   object
# dtypes: float64(7), object(1)
# memory usage: 137.6+ KB

# %%
df.size
# Out:
# 17600

# %%
df.shape
# Out:
# (2200, 8)

# %%
df.columns
# Out:
# Index(['Nitrogen', 'phosphorus', 'potassium', 'temperature', 'humidity', 'ph',
#        'rainfall', 'Crops'],
#       dtype='object')

# %%
df.head(10)
# Out:
#    Nitrogen  phosphorus  potassium  ...        ph    rainfall  Crops
# 0      90.0        42.0       43.0  ...  6.502985  202.935536   rice
# 1      85.0        58.0       41.0  ...  7.038096  226.655537   rice
# 2      60.0        55.0       44.0  ...       NaN  263.964248   rice
# 3      74.0        35.0       40.0  ...  6.980401  242.864034   rice
# 4      78.0        42.0       42.0  ...  7.628473  262.717340   rice
# 5      69.0        37.0       42.0  ...  7.073454  251.055000   rice
# 6       NaN        55.0       38.0  ...  5.700806  271.324860   rice
# 7      94.0        53.0       40.0  ...  5.718627  241.974195   rice
# 8      89.0        54.0       38.0  ...  6.685346         NaN   rice
# 9      68.0        58.0       38.0  ...  6.336254  221.209196   rice
#
# [10 rows x 8 columns]

# %%
df.tail(10)
# Out:
#       Nitrogen  phosphorus  potassium  ...        ph    rainfall  Crops
# 2190     103.0        40.0       30.0  ...  6.348316  141.483164    Tea
# 2191     118.0         NaN       34.0  ...  6.123796  181.417081    Tea
# 2192     106.0        21.0       35.0  ...       NaN  188.550654    Tea
# 2193     116.0        38.0       34.0  ...  6.020947  183.468585    Tea
# 2194      97.0        35.0       26.0  ...  6.334610  166.254931    Tea
# 2195     107.0        34.0       32.0  ...  6.780064  177.774507    Tea
# 2196      99.0        15.0       27.0  ...  6.086922  127.924610    Tea
# 2197     118.0        33.0       30.0  ...  6.362608  173.322839    Tea
# 2198     117.0        32.0       34.0  ...  6.758793  127.175293    Tea
# 2199     104.0        18.0       30.0  ...  6.779833  140.937041    Tea
#
# [10 rows x 8 columns]

# %%
#Describe function used to find the total count,mean,Standard deviation,minimum value,maximum value
#20,50,70 percentage of the dataset value
df.describe()
# Out:
#           Nitrogen   phosphorus  ...           ph     rainfall
# count  2163.000000  2139.000000  ...  2048.000000  2158.000000
# mean     50.803514    53.455820  ...     6.469706   103.439924
# std      36.958470    33.045385  ...     0.776121    54.947556
# min       0.000000     5.000000  ...     3.504752    20.211267
# 25%      21.000000    28.000000  ...     5.964534    64.428291
# 50%      37.000000    51.000000  ...     6.425045    94.762562
# 75%      85.000000    68.000000  ...     6.928163   124.408005
# max     140.000000   145.000000  ...     9.935091   298.560117
#
# [8 rows x 7 columns]

# %%
#Showing Which rows are null value
null_rows= df[df.isnull().T.any().T]
null_rows
# Out:
#       Nitrogen  phosphorus  potassium  ...        ph    rainfall  Crops
# 2         60.0        55.0       44.0  ...       NaN  263.964248   rice
# 4         78.0        42.0       42.0  ...  7.628473  262.717340   rice
# 6          NaN        55.0       38.0  ...  5.700806  271.324860   rice
# 8         89.0        54.0       38.0  ...  6.685346         NaN   rice
# 14        94.0        50.0       37.0  ...  6.948020  209.586971   rice
# ...        ...         ...        ...  ...       ...         ...    ...
# 2185     116.0        36.0       25.0  ...  6.172090  156.681037    Tea
# 2188     107.0        31.0       31.0  ...       NaN  153.120164    Tea
# 2191     118.0         NaN       34.0  ...  6.123796  181.417081    Tea
# 2192     106.0        21.0       35.0  ...       NaN  188.550654    Tea
# 2197     118.0        33.0       30.0  ...  6.362608  173.322839    Tea
#
# [457 rows x 8 columns]

# %%
#nullvalue specific column
null_specific_column=df[df['humidity'].isnull()]
null_specific_column
# Out:
#       Nitrogen  phosphorus  potassium  ...        ph    rainfall   Crops
# 14        94.0        50.0       37.0  ...  6.948020  209.586971    rice
# 25        66.0        53.0       41.0  ...  7.778915  257.003887    rice
# 139       76.0        57.0       18.0  ...  6.092726   94.262494  Bhutta
# 200       40.0        72.0       77.0  ...  7.485996   88.551231   Chola
# 297       36.0        56.0       83.0  ...  7.452671   69.095125   Chola
# ...        ...         ...        ...  ...       ...         ...     ...
# 2102      83.0        38.0       35.0  ...  7.189156  136.732509     Tea
# 2126      86.0        26.0       27.0  ...  6.081173  192.428038     Tea
# 2169     111.0        28.0       26.0  ...  6.937353  192.712124     Tea
# 2185     116.0        36.0       25.0  ...  6.172090  156.681037     Tea
# 2197     118.0        33.0       30.0  ...  6.362608  173.322839     Tea
#
# [71 rows x 8 columns]

# %%
#duplicate rows
duplicate_rows= df[df.duplicated()]
duplicate_rows
# Out:
# Empty DataFrame
# Columns: [Nitrogen, phosphorus, potassium, temperature, humidity, ph, rainfall, Crops]
# Index: []

# %%
#how many nulls
print(df.isnull().sum())
# Out:
# Nitrogen        37
# phosphorus      61
# potassium       65
# temperature     63
# humidity        71
# ph             152
# rainfall        42
# Crops            0
# dtype: int64

# %%
#remove null value /sub set(specify columns)
df = df.dropna(subset=['humidity','ph'])
df
# Out:
#       Nitrogen  phosphorus  potassium  ...        ph    rainfall  Crops
# 0         90.0        42.0       43.0  ...  6.502985  202.935536   rice
# 1         85.0        58.0       41.0  ...  7.038096  226.655537   rice
# 3         74.0        35.0       40.0  ...  6.980401  242.864034   rice
# 4         78.0        42.0       42.0  ...  7.628473  262.717340   rice
# 5         69.0        37.0       42.0  ...  7.073454  251.055000   rice
# ...        ...         ...        ...  ...       ...         ...    ...
# 2194      97.0        35.0       26.0  ...  6.334610  166.254931    Tea
# 2195     107.0        34.0       32.0  ...  6.780064  177.774507    Tea
# 2196      99.0        15.0       27.0  ...  6.086922  127.924610    Tea
# 2198     117.0        32.0       34.0  ...  6.758793  127.175293    Tea
# 2199     104.0        18.0       30.0  ...  6.779833  140.937041    Tea
#
# [1979 rows x 8 columns]

# %%
#all null values remove
df = df.dropna(how='any',axis=0)
df
# Out:
#       Nitrogen  phosphorus  potassium  ...        ph    rainfall  Crops
# 0         90.0        42.0       43.0  ...  6.502985  202.935536   rice
# 1         85.0        58.0       41.0  ...  7.038096  226.655537   rice
# 3         74.0        35.0       40.0  ...  6.980401  242.864034   rice
# 5         69.0        37.0       42.0  ...  7.073454  251.055000   rice
# 7         94.0        53.0       40.0  ...  5.718627  241.974195   rice
# ...        ...         ...        ...  ...       ...         ...    ...
# 2194      97.0        35.0       26.0  ...  6.334610  166.254931    Tea
# 2195     107.0        34.0       32.0  ...  6.780064  177.774507    Tea
# 2196      99.0        15.0       27.0  ...  6.086922  127.924610    Tea
# 2198     117.0        32.0       34.0  ...  6.758793  127.175293    Tea
# 2199     104.0        18.0       30.0  ...  6.779833  140.937041    Tea
#
# [1743 rows x 8 columns]

# %%
#applaing aging to check and showing null value
df.isnull().sum().sum()
# Out:
# 0

# %%
#remove duplicate data
df.drop_duplicates(keep=False, inplace=True)
df
# Out:
#       Nitrogen  phosphorus  potassium  ...        ph    rainfall  Crops
# 0         90.0        42.0       43.0  ...  6.502985  202.935536   rice
# 1         85.0        58.0       41.0  ...  7.038096  226.655537   rice
# 3         74.0        35.0       40.0  ...  6.980401  242.864034   rice
# 5         69.0        37.0       42.0  ...  7.073454  251.055000   rice
# 7         94.0        53.0       40.0  ...  5.718627  241.974195   rice
# ...        ...         ...        ...  ...       ...         ...    ...
# 2194      97.0        35.0       26.0  ...  6.334610  166.254931    Tea
# 2195     107.0        34.0       32.0  ...  6.780064  177.774507    Tea
# 2196      99.0        15.0       27.0  ...  6.086922  127.924610    Tea
# 2198     117.0        32.0       34.0  ...  6.758793  127.175293    Tea
# 2199     104.0        18.0       30.0  ...  6.779833  140.937041    Tea
#
# [1743 rows x 8 columns]

# %%
#applaing aging to check and showing duplicate rows
duplicate_rows= df[df.duplicated()]
duplicate_rows
# Out:
# Empty DataFrame
# Columns: [Nitrogen, phosphorus, potassium, temperature, humidity, ph, rainfall, Crops]
# Index: []

# %%
#applaing aging to check and showing duplicate rows
len(duplicate_rows)
# Out:
# 0

# %%
df.dtypes
# Out:
# Nitrogen       float64
# phosphorus     float64
# potassium      float64
# temperature    float64
# humidity       float64
# ph             float64
# rainfall       float64
# Crops           object
# dtype: object

# %% [markdown]
# # **Initial Data Visualization**

# %%
sns.heatmap(df.corr(),annot=True)

# %%
features = df[['Nitrogen','phosphorus', 'potassium', 'temperature', 'humidity', 'ph',
       'rainfall']]
target = df['Crops']
Crops = df['Crops']

# %%
acc = []
model = []

# %% [markdown]
# # **performance Model Train**

# %%
from sklearn.model_selection import train_test_split
Xtrain, Xtest, Ytrain, Ytest = train_test_split(features,target,test_size = 0.2,random_state =2)

# %% [markdown]
# DecisionTree

# %%
from sklearn.tree import DecisionTreeClassifier

DecisionTree = DecisionTreeClassifier(criterion="entropy",random_state=2,max_depth=5)

DecisionTree.fit(Xtrain,Ytrain)

predicted_values = DecisionTree.predict(Xtest)
x = metrics.accuracy_score(Ytest, predicted_values)
acc.append(x)
model.append('Decision Tree')
print("DecisionTrees's Accuracy is: ", x*100)

print(classification_report(Ytest,predicted_values))
print("Confusion Matrix on Test Data")
pd.crosstab(Ytest, predicted_values, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# DecisionTrees's Accuracy is:  86.24641833810888
#                 precision    recall  f1-score   support
#
#         Banana       0.92      1.00      0.96        12
#         Bhangi       0.95      1.00      0.98        21
#         Bhutta       1.00      0.94      0.97        16
#          Chola       1.00      0.94      0.97        16
#         Dhalim       1.00      1.00      1.00        12
# Khesharir Dhal       0.00      0.00      0.00        18
#    Moshur Dhal       0.00      0.00      0.00        12
#     Motorshuti       0.58      1.00      0.73        47
#           Shim       1.00      1.00      1.00        15
#            Tea       1.00      0.90      0.95        21
#         Tormuj       0.93      1.00      0.96        13
#          apple       1.00      1.00      1.00        24
#        coconut       1.00      1.00      1.00        16
#         cotton       0.92      1.00      0.96        12
#         grapes       1.00      1.00      1.00        14
#           jute       0.62      0.94      0.75        16
#          mango       1.00      0.69      0.82        13
#         orange       1.00      1.00      1.00        18
#         papaya       1.00      0.85      0.92        13
#           rice       0.93      0.65      0.76        20
#
#       accuracy                           0.86       349
#      macro avg       0.84      0.85      0.84       349
#   weighted avg       0.83      0.86      0.83       349
#
# Confusion Matrix on Test Data
# Predicted       Banana  Bhangi  Bhutta  Chola  ...  orange  papaya  rice  All
# True                                           ...
# Banana              12       0       0      0  ...       0       0     0   12
# Bhangi               0      21       0      0  ...       0       0     0   21
# Bhutta               0       0      15      0  ...       0       0     0   16
# Chola                1       0       0     15  ...       0       0     0   16
# Dhalim               0       0       0      0  ...       0       0     0   12
# Khesharir Dhal       0       0       0      0  ...       0       0     0   18
# Moshur Dhal          0       0       0      0  ...       0       0     0   12
# Motorshuti           0       0       0      0  ...       0       0     0   47
# Shim                 0       0       0      0  ...       0       0     0   15
# Tea                  0       1       0      0  ...       0       0     0   21
# Tormuj               0       0       0      0  ...       0       0     0   13
# apple                0       0       0      0  ...       0       0     0   24
# coconut              0       0       0      0  ...       0       0     0   16
# cotton               0       0       0      0  ...       0       0     0   12
# grapes               0       0       0      0  ...       0       0     0   14
# jute                 0       0       0      0  ...       0       0     1   16
# mango                0       0       0      0  ...       0       0     0   13
# orange               0       0       0      0  ...      18       0     0   18
# papaya               0       0       0      0  ...       0      11     0   13
# rice                 0       0       0      0  ...       0       0    13   20
# All                 13      22      15     15  ...      18      11    14  349
#
# [21 rows x 19 columns]

# %%
from sklearn.model_selection import cross_val_score

# %%
# Cross validation score (Decision Tree)
score = cross_val_score(DecisionTree, features, target,cv=5)

# %%
score
# Out:
# array([0.88252149, 0.88252149, 0.87106017, 0.84770115, 0.85057471])

# %%
import pickle
DT_pkl_filename = 'DecisionTree.pkl'
DT_Model_pkl = open(DT_pkl_filename, 'wb')
pickle.dump(DecisionTree, DT_Model_pkl)
DT_Model_pkl.close()

# %% [markdown]
# Gaussian Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

NaiveBayes = GaussianNB()

NaiveBayes.fit(Xtrain,Ytrain)

predicted_values = NaiveBayes.predict(Xtest)
x = metrics.accuracy_score(Ytest, predicted_values)
acc.append(x)
model.append('Naive Bayes')
print("Naive Bayes's Accuracy is: ", x*100)

print(classification_report(Ytest,predicted_values))
print("Confusion Matrix on Test Data")
pd.crosstab(Ytest, predicted_values, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# Naive Bayes's Accuracy is:  0.9856733524355301
#                 precision    recall  f1-score   support
#
#         Banana       1.00      1.00      1.00        12
#         Bhangi       1.00      1.00      1.00        21
#         Bhutta       1.00      0.94      0.97        16
#          Chola       1.00      1.00      1.00        16
#         Dhalim       1.00      1.00      1.00        12
# Khesharir Dhal       1.00      1.00      1.00        18
#    Moshur Dhal       1.00      1.00      1.00        12
#     Motorshuti       1.00      1.00      1.00        47
#           Shim       1.00      1.00      1.00        15
#            Tea       1.00      1.00      1.00        21
#         Tormuj       1.00      1.00      1.00        13
#          apple       1.00      1.00      1.00        24
#        coconut       1.00      1.00      1.00        16
#         cotton       0.92      1.00      0.96        12
#         grapes       1.00      1.00      1.00        14
#           jute       0.80      1.00      0.89        16
#          mango       1.00      1.00      1.00        13
#         orange       1.00      1.00      1.00        18
#         papaya       1.00      1.00      1.00        13
#           rice       1.00      0.80      0.89        20
#
#       accuracy                           0.99       349
#      macro avg       0.99      0.99      0.99       349
#   weighted avg       0.99      0.99      0.99       349
#
# Confusion Matrix on Test Data
# Predicted       Banana  Bhangi  Bhutta  Chola  ...  orange  papaya  rice  All
# True                                           ...
# Banana              12       0       0      0  ...       0       0     0   12
# Bhangi               0      21       0      0  ...       0       0     0   21
# Bhutta               0       0      15      0  ...       0       0     0   16
# Chola                0       0       0     16  ...       0       0     0   16
# Dhalim               0       0       0      0  ...       0       0     0   12
# Khesharir Dhal       0       0       0      0  ...       0       0     0   18
# Moshur Dhal          0       0       0      0  ...       0       0     0   12
# Motorshuti           0       0       0      0  ...       0       0     0   47
# Shim                 0       0       0      0  ...       0       0     0   15
# Tea                  0       0       0      0  ...       0       0     0   21
# Tormuj               0       0       0      0  ...       0       0     0   13
# apple                0       0       0      0  ...       0       0     0   24
# coconut              0       0       0      0  ...       0       0     0   16
# cotton               0       0       0      0  ...       0       0     0   12
# grapes               0       0       0      0  ...       0       0     0   14
# jute                 0       0       0      0  ...       0       0     0   16
# mango                0       0       0      0  ...       0       0     0   13
# orange               0       0       0      0  ...      18       0     0   18
# papaya               0       0       0      0  ...       0      13     0   13
# rice                 0       0       0      0  ...       0       0    16   20
# All                 12      21      15     16  ...      18      13    16  349
#
# [21 rows x 21 columns]

# %%
# Cross validation score (NaiveBayes)
score = cross_val_score(NaiveBayes,features,target,cv=5)
score
# Out:
# array([0.99140401, 0.98567335, 0.99426934, 0.99425287, 0.99137931])

# %%
import pickle
NB_pkl_filename = 'NBClassifier.pkl'
NB_Model_pkl = open(NB_pkl_filename, 'wb')
pickle.dump(NaiveBayes, NB_Model_pkl)
NB_Model_pkl.close()

# %% [markdown]
# Support Vector Machine

# %%
from sklearn.svm import SVC

SVM = SVC(gamma='auto')

SVM.fit(Xtrain,Ytrain)

predicted_values = SVM.predict(Xtest)

x = metrics.accuracy_score(Ytest, predicted_values)
acc.append(x)
model.append('SVM')
print("SVM's Accuracy is: ", x*100)

print(classification_report(Ytest,predicted_values))
print("Confusion Matrix on Test Data")
pd.crosstab(Ytest, predicted_values, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# SVM's Accuracy is:  0.1346704871060172
#                 precision    recall  f1-score   support
#
#         Banana       0.00      0.00      0.00        12
#         Bhangi       0.00      0.00      0.00        21
#         Bhutta       0.00      0.00      0.00        16
#          Chola       0.00      0.00      0.00        16
#         Dhalim       0.00      0.00      0.00        12
# Khesharir Dhal       0.00      0.00      0.00        18
#    Moshur Dhal       0.00      0.00      0.00        12
#     Motorshuti       0.13      1.00      0.24        47
#           Shim       0.00      0.00      0.00        15
#            Tea       0.00      0.00      0.00        21
#         Tormuj       0.00      0.00      0.00        13
#          apple       0.00      0.00      0.00        24
#        coconut       0.00      0.00      0.00        16
#         cotton       0.00      0.00      0.00        12
#         grapes       0.00      0.00      0.00        14
#           jute       0.00      0.00      0.00        16
#          mango       0.00      0.00      0.00        13
#         orange       0.00      0.00      0.00        18
#         papaya       0.00      0.00      0.00        13
#           rice       0.00      0.00      0.00        20
#
#       accuracy                           0.13       349
#      macro avg       0.01      0.05      0.01       349
#   weighted avg       0.02      0.13      0.03       349
#
# Confusion Matrix on Test Data
# Predicted       Motorshuti  All
# True
# Banana                  12   12
# Bhangi                  21   21
# Bhutta                  16   16
# Chola                   16   16
# Dhalim                  12   12
# Khesharir Dhal          18   18
# Moshur Dhal             12   12
# Motorshuti              47   47
# Shim                    15   15
# Tea                     21   21
# Tormuj                  13   13
# apple                   24   24
# coconut                 16   16
# cotton                  12   12
# grapes                  14   14
# jute                    16   16
# mango                   13   13
# orange                  18   18
# papaya                  13   13
# rice                    20   20
# All                    349  349

# %%
# Cross validation score (SVM)
score = cross_val_score(SVM,features,target,cv=5)
score
# Out:
# array([0.14040115, 0.14326648, 0.14040115, 0.13793103, 0.1408046 ])

# %% [markdown]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

LogReg = LogisticRegression(random_state=2)

LogReg.fit(Xtrain,Ytrain)

predicted_values = LogReg.predict(Xtest)

x = metrics.accuracy_score(Ytest, predicted_values)
acc.append(x)
model.append('Logistic Regression')
print("Logistic Regression's Accuracy is: ", x*100)

print(classification_report(Ytest,predicted_values))
print("Confusion Matrix on Test Data")
pd.crosstab(Ytest, predicted_values, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# Logistic Regression's Accuracy is:  0.9111747851002865
#                 precision    recall  f1-score   support
#
#         Banana       1.00      1.00      1.00        12
#         Bhangi       1.00      1.00      1.00        21
#         Bhutta       0.92      0.75      0.83        16
#          Chola       1.00      1.00      1.00        16
#         Dhalim       0.86      1.00      0.92        12
# Khesharir Dhal       0.75      0.50      0.60        18
#    Moshur Dhal       0.71      0.83      0.77        12
#     Motorshuti       0.88      0.96      0.92        47
#           Shim       1.00      1.00      1.00        15
#            Tea       1.00      0.90      0.95        21
#         Tormuj       1.00      1.00      1.00        13
#          apple       1.00      1.00      1.00        24
#        coconut       1.00      0.88      0.93        16
#         cotton       0.73      0.92      0.81        12
#         grapes       1.00      1.00      1.00        14
#           jute       0.62      0.81      0.70        16
#          mango       1.00      1.00      1.00        13
#         orange       1.00      1.00      1.00        18
#         papaya       0.87      1.00      0.93        13
#           rice       0.93      0.70      0.80        20
#
#       accuracy                           0.91       349
#      macro avg       0.91      0.91      0.91       349
#   weighted avg       0.92      0.91      0.91       349
#
# Confusion Matrix on Test Data
# Predicted       Banana  Bhangi  Bhutta  Chola  ...  orange  papaya  rice  All
# True                                           ...
# Banana              12       0       0      0  ...       0       0     0   12
# Bhangi               0      21       0      0  ...       0       0     0   21
# Bhutta               0       0      12      0  ...       0       0     0   16
# Chola                0       0       0     16  ...       0       0     0   16
# Dhalim               0       0       0      0  ...       0       0     0   12
# Khesharir Dhal       0       0       0      0  ...       0       0     0   18
# Moshur Dhal          0       0       0      0  ...       0       0     0   12
# Motorshuti           0       0       0      0  ...       0       0     0   47
# Shim                 0       0       0      0  ...       0       0     0   15
# Tea                  0       0       0      0  ...       0       0     0   21
# Tormuj               0       0       0      0  ...       0       0     0   13
# apple                0       0       0      0  ...       0       0     0   24
# coconut              0       0       0      0  ...       0       0     0   16
# cotton               0       0       1      0  ...       0       0     0   12
# grapes               0       0       0      0  ...       0       0     0   14
# jute                 0       0       0      0  ...       0       2     1   16
# mango                0       0       0      0  ...       0       0     0   13
# orange               0       0       0      0  ...      18       0     0   18
# papaya               0       0       0      0  ...       0      13     0   13
# rice                 0       0       0      0  ...       0       0    14   20
# All                 12      21      13     16  ...      18      15    15  349
#
# [21 rows x 21 columns]

# %%
# Cross validation score (Logistic Regression)
score = cross_val_score(LogReg,features,target,cv=5)
score
# Out:
# array([0.9226361 , 0.91977077, 0.92550143, 0.94827586, 0.93103448])

# %%
import pickle
LR_pkl_filename = 'LogisticRegression.pkl'
LR_Model_pkl = open(DT_pkl_filename, 'wb')
pickle.dump(LogReg, LR_Model_pkl)
LR_Model_pkl.close()

# %% [markdown]
# Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

RF = RandomForestClassifier(n_estimators=20, random_state=0)
RF.fit(Xtrain,Ytrain)

predicted_values = RF.predict(Xtest)

x = metrics.accuracy_score(Ytest, predicted_values)
acc.append(x)
model.append('RF')
print("RF's Accuracy is: ", x*100)

print(classification_report(Ytest,predicted_values))
print("Confusion Matrix on Test Data")
pd.crosstab(Ytest, predicted_values, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# RF's Accuracy is:  0.9856733524355301
#                 precision    recall  f1-score   support
#
#         Banana       1.00      1.00      1.00        12
#         Bhangi       1.00      1.00      1.00        21
#         Bhutta       1.00      1.00      1.00        16
#          Chola       1.00      1.00      1.00        16
#         Dhalim       1.00      1.00      1.00        12
# Khesharir Dhal       1.00      1.00      1.00        18
#    Moshur Dhal       1.00      1.00      1.00        12
#     Motorshuti       1.00      1.00      1.00        47
#           Shim       1.00      1.00      1.00        15
#            Tea       1.00      1.00      1.00        21
#         Tormuj       1.00      1.00      1.00        13
#          apple       1.00      1.00      1.00        24
#        coconut       1.00      1.00      1.00        16
#         cotton       1.00      1.00      1.00        12
#         grapes       1.00      1.00      1.00        14
#           jute       0.79      0.94      0.86        16
#          mango       1.00      1.00      1.00        13
#         orange       1.00      1.00      1.00        18
#         papaya       1.00      1.00      1.00        13
#           rice       0.94      0.80      0.86        20
#
#       accuracy                           0.99       349
#      macro avg       0.99      0.99      0.99       349
#   weighted avg       0.99      0.99      0.99       349
#
# Confusion Matrix on Test Data
# Predicted       Banana  Bhangi  Bhutta  Chola  ...  orange  papaya  rice  All
# True                                           ...
# Banana              12       0       0      0  ...       0       0     0   12
# Bhangi               0      21       0      0  ...       0       0     0   21
# Bhutta               0       0      16      0  ...       0       0     0   16
# Chola                0       0       0     16  ...       0       0     0   16
# Dhalim               0       0       0      0  ...       0       0     0   12
# Khesharir Dhal       0       0       0      0  ...       0       0     0   18
# Moshur Dhal          0       0       0      0  ...       0       0     0   12
# Motorshuti           0       0       0      0  ...       0       0     0   47
# Shim                 0       0       0      0  ...       0       0     0   15
# Tea                  0       0       0      0  ...       0       0     0   21
# Tormuj               0       0       0      0  ...       0       0     0   13
# apple                0       0       0      0  ...       0       0     0   24
# coconut              0       0       0      0  ...       0       0     0   16
# cotton               0       0       0      0  ...       0       0     0   12
# grapes               0       0       0      0  ...       0       0     0   14
# jute                 0       0       0      0  ...       0       0     1   16
# mango                0       0       0      0  ...       0       0     0   13
# orange               0       0       0      0  ...      18       0     0   18
# papaya               0       0       0      0  ...       0      13     0   13
# rice                 0       0       0      0  ...       0       0    16   20
# All                 12      21      16     16  ...      18      13    17  349
#
# [21 rows x 21 columns]

# %%
# Cross validation score (Random Forest)
score = cross_val_score(RF,features,target,cv=5)
score
# Out:
# array([0.98853868, 0.99140401, 0.98567335, 0.99137931, 0.99137931])

# %%
import pickle
RF_pkl_filename = 'RandomForest.pkl'
RF_Model_pkl = open(RF_pkl_filename, 'wb')
pickle.dump(RF, RF_Model_pkl)
RF_Model_pkl.close()

# %%
plt.figure(figsize=[10,5],dpi = 100)
plt.title('Accuracy Comparison')
plt.xlabel('Accuracy')
plt.ylabel('Algorithm')
sns.barplot(x = acc,y = model,palette='dark')

# %%
accuracy_models = dict(zip(model, acc))
for k, v in accuracy_models.items():
    print (k, '-->', v)
# Out:
# Decision Tree --> 0.8624641833810889
# Naive Bayes --> 0.9856733524355301
# SVM --> 0.1346704871060172
# Logistic Regression --> 0.9111747851002865
# RF --> 0.9856733524355301

# %%
data = np.array([[104,18, 30, 23.603016, 60.3, 6.7, 140.91]])
prediction = RF.predict(data)
print(prediction)
# Out:
# ['Tea']

# %%
data = np.array([[83, 45, 60, 28, 70.3, 7.0, 150.9]])
prediction = RF.predict(data)
print(prediction)
# Out:
# ['Tea']

# %%
data = np.array([[60, 50, 55, 77, 65.3, 5.0, 100.9]])
prediction = RF.predict(data)
print(prediction)
# Out:
# ['papaya']

# %%
data = np.array([[70, 80, 50, 75, 63.3, 4.0, 90.9]])
prediction = RF.predict(data)
print(prediction)
# Out:
# ['Banana']

# %%
data = np.array([[3, 10, 0, 35, 3.3, 7.5, 9.9]])
prediction = RF.predict(data)
print(prediction)
# Out:
# ['Bhangi']
